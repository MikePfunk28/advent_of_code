# %%
import re
import typing


class Solution:
    def roman_to_int(self, s: str) -> int:
        values = {
            "I": 1,
            "V": 5,
            "X": 10,
            "L": 50,
            "C": 100,
            "D": 500,
            "M": 1000,
        }
        total = 0
        

        for i in range(len(s)):
            current_symbol = s[i]
            print(repr(current_symbol))
            current_val = values[current_symbol]

            if i + 1 < len(s):
                next_symbol = s[i + 1]
                next_val = values[next_symbol]
            else:
                next_val = 0
            
            if current_val < next_val:
                total -= current_val
            else:
                total += current_val

        return total

if __name__ == "__main__":
    solution = Solution()
    s = input().strip()
    print(solution.roman_to_int(s))
# Out:
# 'V'
# 'I'
# 'I'
# 'I'
# 8

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        values = {
            "I": 1,
            "V": 5,
            "X": 10,
            "L": 50,
            "C": 100,
            "D": 500,
            "M": 1000,
        }
        total = 0
        

        for i in range(len(s)):
            current_symbol = s[i]
            print(repr(current_symbol))
            current_val = values[current_symbol]

            if i + 1 < len(s):
                next_symbol = s[i + 1]
                next_val = values[next_symbol]
            else:
                next_val = 0
            
            if current_val < next_val:
                total -= current_val
            else:
                total += current_val

        return total

# %% [markdown]
# ## Faster/Cleaner
#
# essentially stop checks on bounds and looks ahead.  Scans right to left.
#
# total = 0
# previous = 0
#
# for char in reversed(s):
#     current = values[char]
#
#     if current_val < previous_val:
#         total -= current
#     else:
#                 total += current
#
#             previous = current
#
# return total

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        values = {
            "I": 1,
            "V": 5,
            "X": 10,
            "L": 50,
            "C": 100,
            "D": 500,
            "M": 1000,
        }

        total = 0
        previous = 0

        for char in reversed(s):
            current = values[char]

            if current < previous:
                total -= current
            else:
                total += current

            previous = current

        return total

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        values = {"I": 1, "V": 5, "X": 10, "L": 50, "C": 100, "D": 500, "M": 1000}
        total = 0
        previous = 0

        for char in reversed(s):
            current = values[char]
            total += -current if current < previous else current
            previous = current

        return total

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        values = {
            "I": 1,
            "V": 5,
            "X": 10,
            "L": 50,
            "C": 100,
            "D": 500,
            "M": 1000,
        }

        total = 0
        previous = 0

        for char in reversed(s):
            current = values[char]

            if current < previous:
                total -= current
            else:
                total += current

            previous = current

        return total
