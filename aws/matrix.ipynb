# %% [markdown]
# ## Matrix
#
# 7 3
# Tsi
# h%x
# i #
# sM
# $a
# #t%
# ir!
#
# 7 rows 3 columns

# %%
#!/bin/python3

import math
import os
import random
import re
import sys




first_multiple_input = input().rstrip().split()

n = int(first_multiple_input[0])

m = int(first_multiple_input[1])

matrix = []

for _ in range(n):
    matrix_item = input()
    
    matrix.append(matrix_item)
    print(matrix)
# Out:
# ['']
# ['', '']
# ['', '', '']
# ['', '', '', '']
# ['', '', '', '', '']
# ['', '', '', '', '', '']
# ['', '', '', '', '', '', '']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import re

matrix = ['Tsi',
          'h%x',
          'i #',
          'sM ',
          '$a ',
          '#t%',
          'ir!']



# read down each col.
for col in zip(*matrix):
    
    inner_col = ''.join(col)
    #print(inner_col)
    new_col = inner_col.replace('$', ' ').replace('%', ' ').replace('#', ' ').replace('!', ' ')
    #print(new_col)
    #print('---------')
    for i in range(len(new_col)):
        #print(new_col[i])
        if new_col[i] == ' ':
            if i > 0 and new_col[i-1] != ' ':
                print(' ', end='')
        else:
            print(new_col[i], end='')

# read all cols concat into a single string
# Out:
# This is Matrix

# %%
## Now do the same without if statements
import re

matrix = ['T%Mic&',
          'h%axr%',
          'iit#p!',
          'ssrst&']


for col in zip(*matrix):
    inner_col = ''.join(col)
    
    new_col = re.sub(r'((?<!=\w)[^\w]+(?!\w))', ' ', inner_col)
    new_col1 = re.sub(r'(?<!\w)[^\w]+(?=\w)|(?<=\w)[^\w\s]+(?!\w)', ' ', inner_col)
    
    print(new_col1, end='')

        

# This isMatrix scrpt&%!&
# Out:
# This isMatrix#scrpt&%!&

# %%
import re

matrix = ['T%Mic&',
          'h%axr%',
          'iit#p!',
          'ssrst&']

# what the columns actually are
cols = [''.join(c) for c in zip(*matrix)]
print("columns:", cols)

# the full decoded string
decoded = ''.join(cols)
print("decoded:", repr(decoded))

# correct: ONE sub on the whole decoded string
print("correct:", repr(re.sub(r'(?<=\w)[^\w]+(?=\w)', ' ', decoded)))

# ---- what YOUR code actually does ----
for col in zip(*matrix):
    inner_col = ''.join(col)
    new_col = re.sub(r'((?<!=\w)[^\w]+(?!\w))', ' ', inner_col)
# this line is OUTSIDE the loop -> inner_col is only the LAST column here:
print("your inner_col at this point:", repr(inner_col))
new_col1 = re.sub(r'(?<!\w)[^\w]+(?=\w)|(?<=\w)[^\w\s]+(?!\w)', ' ', inner_col)
print("your new_col1 prints:", repr(new_col1))
print(new_col1)
# Out:
# columns: ['This', '%%is', 'Matr', 'ix#s', 'crpt', '&%!&']
# decoded: 'This%%isMatrix#scrpt&%!&'
# correct: 'This isMatrix scrpt&%!&'
# your inner_col at this point: 'This'
# your new_col1 prints: 'This'
# This
# your inner_col at this point: '%%is'
# your new_col1 prints: ' is'
#  is
# your inner_col at this point: 'Matr'
# your new_col1 prints: 'Matr'
# Matr
# your inner_col at this point: 'ix#s'
# your new_col1 prints: 'ix#s'
# ix#s
# your inner_col at this point: 'crpt'
# your new_col1 prints: 'crpt'
# crpt
# your inner_col at this point: '&%!&'
# your new_col1 prints: '&%!&'
# &%!&
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#!/bin/python3

import math
import os
import random
import re
import sys




first_multiple_input = input().rstrip().split()

n = int(first_multiple_input[0])

m = int(first_multiple_input[1])

matrix = []

for _ in range(n):
    
    matrix_item = input()
    matrix.append(matrix_item)
    
    
    
# what the columns actually are
cols = [''.join(c) for c in zip(*matrix)]
#print("columns:", cols)

# the full decoded string
decoded = ''.join(cols)
#print("decoded:", repr(decoded))

# correct: ONE sub on the whole decoded string
print(re.sub(r'(?<=\w)[^\w]+(?=\w)', ' ', decoded))
