# %% [markdown]
# ## Heap
#
# Heap API
# ```
# class Heap {
#   top()
#   peek()
#   insert(element, priority)
#   remove(element)
#   update(element, newPriority)
# }
# ```

# %%
class DHeap:
    def __init__(self, d):
        self.d = d
        self.heap = []

    def parent(self, i):
        return (i - 1) // self.d

    def children(self, i):
        return [self.d * i + j + 1 for j in range(self.d)]

    def insert(self, key):
        self.heap.append(key)
        self._heapify_up(len(self.heap) - 1)

    def _heapify_up(self, index):
        while index > 0:
            parent_index = self.parent(index)
            if self.heap[index] < self.heap[parent_index]:
                self.heap[index], self.heap[parent_index] = self.heap[parent_index], self.heap[index]
                index = parent_index
            else:
                break

            """function bubbleUp(pairs, index=len(pairs)-1)                                ❶
                parentIndex ← index                                                    ❷
                while parentIndex > 0 do                                               ❸
                    currentIndex ← parentIndex
                    parentIndex ← getParentIndex(parentIndex)                            ❹
                if pairs[parentIndex].priority < pairs[currentIndex].priority then   ❺
                    swap(pairs, currentIndex, parentIndex)                             ❻
                else                                                                 ❼
                    break"""

    def extract_min(self):
        if not self.heap:
            raise IndexError("Heap is empty")
        min_element = self.heap[0]
        last_element = self.heap.pop()
        if self.heap:
            self.heap[0] = last_element
            self._heapify_down(0)
        return min_element

    def _heapify_down(self, index):
        smallest = index
        for child_index in self.children(index):
            if child_index < len(self.heap) and self.heap[child_index] < self.heap[smallest]:
                smallest = child_index
        if smallest != index:
            self.heap[index], self.heap[smallest] = self.heap[smallest], self.heap[index]
            self._heapify_down(smallest)

    def peek_min(self):
        if not self.heap:
            raise IndexError("Heap is empty")
        return self.heap[0]

    def size(self):
        return len(self.heap)
    
    def is_empty(self):
        if len(self.heap) == 0:
            return True
        return False

# %%
def _heapify_up(self, index):
    while index > 0:
        parent_index = self.parent(index)
        if self.heap[index] < self.heap[parent_index]:
            self.heap[index], self.heap[parent_index] = self.heap[parent_index], self.heap[index]
            index = parent_index
        else:
            break

# %%
# maxheap, priority queue, d-ary heap, minheap
class maxHeap:
    def __init__(self, pairs):
        self.pairs = pairs
        pairs = []
        
    def bubble_up(pairs, index):
        #self.pairs = pairs
        current_index = pairs[index]
        while index > 0:
            parent_index = getParentIndex(index)
            if pairs[parent_index].priority < current_index.priority:
                swap(pairs, index, parent_index)
                index = parent_index
            else:
                break

    def insert(self, pair):
        self.pairs.append(pair)
        self.bubble_up(self.pairs, len(self.pairs) -1)

    def print_heap(self):
        return(self.pairs)

my_list = [5, 3, 8, 1, 2]
my_heap = maxHeap(my_list) # Binary heap
my_list.bubble_up(3) # Bubble up the element at index 3 (value 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 27
#      23         return(self.pairs)
#      24
#      25 my_list = [5, 3, 8, 1, 2]
#      26 my_heap = maxHeap(my_list) # Binary heap
# ---> 27 my_list.bubble_up(3) # Bubble up the element at index 3 (value 1)
#
# AttributeError: 'list' object has no attribute 'bubble_up'

# %%
void max_heapify (int Arr[ ], int i, int N)
{
    int left = 2*i                   //left child
    int right = 2*i +1           //right child
    if(left<= N and Arr[left] > Arr[i] )
          largest = left;
    else
         largest = i;
    if(right <= N and Arr[right] > Arr[largest] )
        largest = right;
    if(largest != i )
    {
        swap (Ar[i] , Arr[largest]);
        max_heapify (Arr, largest,N);
    } 
 }

# %%
from typing import List

def max_heapify(arr: List[int] = [], n: int=0, i: int=0) -> None:
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2

    if left < n and arr[left] > arr[largest]:
        largest = left

    if right < n and arr[right] > arr[largest]:
        largest = right

    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        max_heapify(arr, n, largest)
    
    print(arr)

def pushdown(arr: List[int] = [], index: int=0) -> None:
    # min heapify down
    n = len(arr)
    while True:
        smallest = index
        left = 2 * index + 1
        right = 2 * index + 2

        if left < n and arr[left] < arr[smallest]:
            smallest = left

        if right < n and arr[right] < arr[smallest]:
            smallest = right

        if smallest != index:
            arr[index], arr[smallest] = arr[smallest], arr[index]
            index = smallest
        else:
            break
    
def enqueue(arr: List[int] = [], key: int=0) -> None:
    arr.append(key)
    n = len(arr)
    for i in range(n // 2 - 1, -1, -1):
        max_heapify(arr, n, i)

def dequque(arr: List[int] = []) -> int:
    if not arr:
        raise IndexError("Heap is empty")
    min_element = arr[0]
    last_element = arr.pop()
    if arr:
        arr[0] = last_element
        pushdown(arr, 0)
    return min_element

my_list = [5, 3, 8, 1, 2, 7, 6]
n = len(my_list)
for i in range(n // 2 - 1, -1, -1):
    max_heapify(my_list, n, i)
enqueue(my_list, 10)
# Out:
# [5, 3, 8, 1, 2, 7, 6]
# [5, 3, 8, 1, 2, 7, 6]
# [8, 3, 7, 1, 2, 5, 6]
# [8, 3, 7, 1, 2, 5, 6]
# [8, 3, 7, 1, 2, 5, 6]
# [8, 3, 7, 10, 2, 5, 6, 1]
# [8, 3, 7, 10, 2, 5, 6, 1]
# [8, 3, 7, 10, 2, 5, 6, 1]
# [8, 10, 7, 3, 2, 5, 6, 1]
# [8, 10, 7, 3, 2, 5, 6, 1]
# [10, 8, 7, 3, 2, 5, 6, 1]
# [10, 8, 7, 3, 2, 5, 6, 1]

# %%
            10
        8      7
      3   2  5   6
    1
